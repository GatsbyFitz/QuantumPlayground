# %% [markdown]
# # Quantum Machine Learning
#
# Application of Quantum Computing to any Machine Learning approach.
#
# ## Types of Machine Learning
#
# Supervised and Unsupervised Learning
#
# https://quantum.cloud.ibm.com/learning/en/courses/quantum-machine-learning/introduction#run-your-first-qml-code
