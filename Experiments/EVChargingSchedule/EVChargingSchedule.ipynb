# %% [markdown]
# # EV Charging Scheduler using Quantum Annealing

# %% [markdown]
# ## The problem
#
# So let's say we are piloting the use of Quantum Computing for scheduling EV charging. We have 1000 EVs to manage, each with unique behaviour profiles (arrival and departure windows), and each with different kWh capacities. The day is split up into 15 minute slots, each slot has a different forecasted energy price.

# %% [markdown]
# ## The approach
# Use of Quantum Annealing
#
# 1. Identifying the parameters and constraints

# %%
#

# %%
# EV Charging Scheduler

# %% [markdown]
# ## Next steps
#
# 1. Testing using Quantum Machine Learning techniques
